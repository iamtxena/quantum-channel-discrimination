# %% [markdown]
# # Print probabilities from results

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

from qcd.optimizationresults.globaloptimizationresults import GlobalOptimizationResults

# %%
results = GlobalOptimizationResults.load_results(file_names=[
    '20210502a_C1_A1_1000_10000_2_0_20',
    '20210321_results_CRS', 
    '20210331_C1_CRS_clons',
    '20210331_C1_DIRECT-L-RAND_clons'],
                                                 path="results/")

# %%
results = GlobalOptimizationResults.load_results(file_names=[
    '20210502b_C1_A1_1000_10000_2_0_20'],
                                                 path="results/")

# %%
results.optimal_configurations
# Out:
# [{'eta_groups': [[0.0, 0.07853981633974483, 0.0],
#    [0.0, 0.15707963267948966, 0.0],
#    [0.0, 0.23561944901923448, 0.0],
#    [0.0, 0.3141592653589793, 0.0],
#    [0.0, 0.39269908169872414, 0.0],
#    [0.0, 0.47123889803846897, 0.0],
#    [0.0, 0.5497787143782138, 0.0],
#    [0.0, 0.6283185307179586, 0.0],
#    [0.0, 0.7068583470577035, 0.0],
#    [0.0, 0.7853981633974483, 0.0],
#    [0.0, 0.8639379797371931, 0.0],
#    [0.0, 0.9424777960769379, 0.0],
#    [0.0, 1.0210176124166828, 0.0],
#    [0.0, 1.0995574287564276, 0.0],
#    [0.0, 1.1780972450961724, 0.0],
#    [0.0, 1.2566370614359172, 0.0],
#    [0.0, 1.335176877775662, 0.0],
#    [0.0, 1.413716694115407, 0.0],
#    [0.0, 1.4922565104551517, 0.0],
#    [0.0, 1.5707963267948966, 0.0],
#    [0.07853981633974483, 0.15707963267948966, 0.0],
#    [0.07853981633974483, 0.23561944901923448, 0.0],
#    [0.07853981633974483, 0.3141592653589793, 0.0],
#    [0.07853981633974483, 0.39269908169872414, 0.0],
#    [0.07853981633974483, 0.47123889803846897, 0.0],
#    [0.07853981633974483, 0.5497787143782138, 0.0],
#    [0.07853981633974483, 0.6283185307179586, 0.0],
#    [0.07853981633974483, 0.7068583470577035, 0.0],
#    [0.07853981633974483, 0.7853981633974483, 0.0],
#    [0.07853981633974483, 0.8639379797371931, 0.0],
#    [0.07853981633974483, 0.9424777960769379, 0.0],
#    [0.07853981633974483, 1.0210176124166828, 0.0],
#    [0.07853981633974483, 1.0995574287564276, 0.0],
#    [0.07853981633974483, 1.1780972450961724, 0.0],
#    [0.07853981633974483, 1.2566370614359172, 0.0],
#    [0.07853981633974483, 1.335176877775662, 0.0],
#    [0.07853981633974483, 1.413716694115407, 0.0],
#    [0.07853981633974483, 1.4922565104551517, 0.0],
#    [0.07853981633974483, 1.5707963267948966, 0.0],
#    [0.15707963267948966, 0.23561944901923448, 0.0],
#    [0.15707963267948966, 0.3141592653589793, 0.0],
#    [0.15707963267948966, 0.39269908169872414, 0.0],
#    [0.15707963267948966, 0.47123889803846897, 0.0],
#    [0.15707963267948966, 0.5497787143782138, 0.0],
#    [0.15707963267948966, 0.6283185307179586, 0.0],
#    [0.15707963267948966, 0.7068583470577035, 0.0],
>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373afca0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373afd90>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373afe80>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373aff70>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738d0a0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738d190>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738d280>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738d370>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738d460>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738d550>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738d640>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738d730>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738d820>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738d910>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738da00>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738daf0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738dbe0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738dcd0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738ddc0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738deb0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738dfa0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373900d0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373901c0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373902b0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373903a0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390490>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390580>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390670>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390760>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390850>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390940>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390a30>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390b20>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390c10>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390d00>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390df0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390ee0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137390fd0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738b100>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738b1f0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738b2e0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738b3d0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738b4c0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738b5b0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738b6a0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738b790>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738b880>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738b970>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738ba60>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738bb50>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738bc40>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738bd30>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738be20>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738bf10>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738c040>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738c130>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738c220>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738c310>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738c400>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738c4f0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738c5e0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738c6d0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738c7c0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1377f09d0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738c970>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738ca60>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738cb50>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738cc40>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738cd30>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738ce20>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x13738cf10>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1040>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1130>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1220>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1310>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1400>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a14f0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a15e0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a16d0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a17c0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a18b0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a19a0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1a90>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1b80>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1c70>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1d60>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1e50>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373a1f40>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388070>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388160>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388250>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388340>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388430>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388520>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388610>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388700>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373887f0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373888e0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373889d0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388ac0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388bb0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388ca0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388d90>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388e80>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137388f70>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373860a0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386190>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386280>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386370>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386460>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386550>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386640>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386730>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386820>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386910>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386a00>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386af0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386be0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386cd0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386dc0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386eb0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x137386fa0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373890d0>,
#    <qcd.configurations.oneshotbaseconfiguration.OneShotConfiguration at 0x1373891c0>],
#   'number_calls_made': [1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1002,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1001,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000,
#    1000]}]

# %%
results.plot_probabilities()

# %%
results.plot_theoretical_probabilities(strategy='one_shot')

# %%
results.plot_theoretical_probabilities(strategy='one_shot_side_entanglement')

# %%
results.plot_probabilities()

# %%
results.plot_amplitudes()

# %% [markdown]
# ## From simulation results loaded previouly extract probabilities
# ### Plot the probabilities for the three simulations

# %%
results.plot_probabilities(results_index=0)

# %%
results.plot_probabilities(results_index=1)

# %%
results.plot_probabilities(results_index=2)

# %% [markdown]
# ## Compare probabilities obtained from both simulations (the first two)
# 1st simulation conditions
#
# 2nd simulation conditions: 3 optimizers and 400 iterations each

# %%
results.plot_probabilities_comparison(results_index1=0,
                                      results_index2=1)

# %%
results.plot_probabilities_comparison(results_index1=1,
                                      results_index2=2,
                                     vmin=-0.2,
                                     vmax=0.2)

# %% [markdown]
# ## Expected results
# ### What are the theoretical results from the paper?

# %%
results.plot_theoretical_probabilities(strategy='one_shot')

# %%
results.plot_theoretical_probabilities(strategy='one_shot_side_entanglement')

# %%
results.plot_theoretical_probabilities_comparison(first_strategy = 'one_shot_side_entanglement',
                                                  second_strategy= 'one_shot')
# Out:
# min: -2.220446049250313e-16, max 0.026917839007302935

# %%
results.plot_theoretical_improvement(vmin =0,
                                     vmax = 0.05)
# Out:
# min: 0.0, max 0.0450848360846548

# %% [markdown]
# ## Compare probabilities from simulations with the theoretical ones from the paper
# ### Simulation 1 vs theory in absolute value

# %%
results.plot_probabilities_comparison_with_theoretical_result(results_index=0,
                                                              strategy='one_shot',
                                                              vmin= -0.02,
                                                              vmax= 0.02)

# %% [markdown]
# ### Simulation 2 vs theory in absolute value

# %%
results.plot_probabilities_comparison_with_theoretical_result(results_index=1,
                                                              strategy='one_shot',
                                                              vmin= -0.25,
                                                              vmax= 0.25)

# %%
results.plot_probabilities_comparison_with_theoretical_result(results_index=2,
                                                              strategy='one_shot',
                                                              vmin= -0.25,
                                                              vmax= 0.25)

# %% [markdown]
# ### Simulation 1 vs theory in percentage

# %%
results.plot_probabilities_comparison_percentage(results_index=0,
                                                 strategy='one_shot',
                                                 vmin= -3,
                                                 vmax= 3)

# %%
results.plot_probabilities_comparison_percentage(results_index=1,
                                                 strategy='one_shot',
                                                 vmin= -40,
                                                 vmax= 40)

# %%
results.plot_probabilities_comparison_percentage(results_index=2,
                                                 strategy='one_shot',
                                                 vmin= -40,
                                                 vmax= 40)

# %% [markdown]
# ## Input state obtained from simulations vs theory
# ### Amplitude $|1>$ from 1st simulation

# %%
results.plot_amplitudes(results_index=0)

# %% [markdown]
# ### Amplitude $|1>$ from 2nd simulation

# %%
results.plot_amplitudes(results_index=1)

# %% [markdown]
# ### Amplitude $|1>$ from 3rd simulation

# %%
results.plot_amplitudes(results_index=2)

# %% [markdown]
# ### Comparing both amplitudes from simulation 1 and 2

# %%
results.plot_amplitudes_comparison(results_index1=0,
                                   results_index2=1)

# %% [markdown]
# ### Comparing both amplitudes from simulation 2 and 3

# %%
results.plot_amplitudes_comparison(results_index1=1,
                                   results_index2=2)

# %% [markdown]
# ### Amplitude $|1>$ expected from theory

# %%
results.plot_theoretical_amplitudes(strategy='one_shot')

# %%
results.plot_theoretical_amplitudes(strategy='one_shot_side_entanglement',
                                    vmin=0,
                                    vmax=0.5,)

# %%
results.plot_theoretical_amplitudes_comparison(first_strategy = 'one_shot',
                                               second_strategy= 'one_shot_side_entanglement',
                                               vmin=0,
                                               vmax=1,
                                               cmap='viridis')

# %% [markdown]
# ## Amplitude deltas when comparing with results from theory
# ### 1st simulation (in absolute value)

# %%
results.plot_amplitudes_comparison_with_theoretical_result(results_index=0,
                                                            strategy='one_shot',
                                                            vmin = -1,
                                                            vmax = 1)

# %% [markdown]
# ### 2nd simulation (in absolute value)

# %%
results.plot_amplitudes_comparison_with_theoretical_result(results_index=1,
                                                            strategy='one_shot',
                                                            vmin = -1,
                                                            vmax = 1)

# %%
results.plot_amplitudes_comparison_with_theoretical_result(results_index=2,
                                                            strategy='one_shot',
                                                            vmin = -1,
                                                            vmax = 1)

# %% [markdown]
# ### 1st simulation (in percentage)

# %%
results.plot_amplitudes_comparison_percentage(results_index=0,
                                              strategy='one_shot',
                                              vmin = -100,
                                              vmax = 100)

# %% [markdown]
# ### 2nd simulation (in percentage)

# %%
results.plot_amplitudes_comparison_percentage(results_index=1,
                                              strategy='one_shot',
                                              vmin = -100,
                                              vmax = 100)

# %%
results.plot_amplitudes_comparison_percentage(results_index=2,
                                              strategy='one_shot',
                                              vmin = -100,
                                              vmax = 100)
