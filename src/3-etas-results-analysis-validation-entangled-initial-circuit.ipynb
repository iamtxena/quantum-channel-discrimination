# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Variables-to-control" data-toc-modified-id="Variables-to-control-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Variables to control</a></span></li><li><span><a href="#Load-and-plot-results" data-toc-modified-id="Load-and-plot-results-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load and plot results</a></span></li></ul></div>

# %% [markdown]
# # Validate 3 channels optimal configuration results

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

from qcd.optimizationresults.globaloptimizationresults import GlobalOptimizationResults
from qcd import save_object_to_disk, load_object_from_file
import numpy as np

# %% [markdown]
# ## Variables to control

# %%
# Filenames with results for 3 etas and their optimized parameters to LOAD
filename = '20210418a_C2_A1_1000_100000_3_6_20'
path = 'results/'

# %% [markdown]
# ## Load and plot results

# %%
results = GlobalOptimizationResults.load_results(file_names=filename,path=path)

# %%
results.validate_optimal_configurations(plays=1000000)
# Out:
# number of eta groups to validate: 120
# Going to validate this eta group: (0, 29, 0)
# Optimal Probability: 42.01% Validated Probability: 41.63 % Difference (absolute value): 0.38%
# Group of etas # 0 of 120
# total time taken so far: 0 minutes and 9 seconds
# Going to validate this eta group: (0, 29, 47)
# Optimal Probability: 51.5% Validated Probability: 51.37 % Difference (absolute value): 0.14%
# Group of etas # 10 of 120
# total time taken so far: 1 minutes and 31 seconds
# Going to validate this eta group: (0, 59, 0)
# Optimal Probability: 58.6% Validated Probability: 58.33 % Difference (absolute value): 0.27%
# Group of etas # 20 of 120
# total time taken so far: 2 minutes and 44 seconds
# Going to validate this eta group: (0, 59, 47)
# Optimal Probability: 58.43% Validated Probability: 58.28 % Difference (absolute value): 0.14%
# Group of etas # 30 of 120
# total time taken so far: 3 minutes and 53 seconds
# Going to validate this eta group: (0, 90, 0)
# Optimal Probability: 66.84% Validated Probability: 66.61 % Difference (absolute value): 0.22%
# Group of etas # 40 of 120
# total time taken so far: 5 minutes and 9 seconds
# Going to validate this eta group: (0, 90, 47)
# Optimal Probability: 66.67% Validated Probability: 66.67 % Difference (absolute value): 0.0%
# Group of etas # 50 of 120
# total time taken so far: 6 minutes and 31 seconds
# Going to validate this eta group: (29, 59, 0)
# Optimal Probability: 58.49% Validated Probability: 58.32 % Difference (absolute value): 0.17%
# Group of etas # 60 of 120
# total time taken so far: 7 minutes and 48 seconds
# Going to validate this eta group: (29, 59, 47)
# Optimal Probability: 50.23% Validated Probability: 50.0 % Difference (absolute value): 0.23%
# Group of etas # 70 of 120
# total time taken so far: 9 minutes and 4 seconds
# Going to validate this eta group: (29, 90, 0)
# Optimal Probability: 66.67% Validated Probability: 66.66 % Difference (absolute value): 0.0%
# Group of etas # 80 of 120
# total time taken so far: 10 minutes and 34 seconds
# Going to validate this eta group: (29, 90, 47)
# Optimal Probability: 58.49% Validated Probability: 58.34 % Difference (absolute value): 0.15%
# Group of etas # 90 of 120
# total time taken so far: 11 minutes and 59 seconds
# Going to validate this eta group: (59, 90, 0)
# Optimal Probability: 66.67% Validated Probability: 66.67 % Difference (absolute value): -0.0%
# Group of etas # 100 of 120
# total time taken so far: 13 minutes and 23 seconds
# Going to validate this eta group: (59, 90, 47)
# Optimal Probability: 49.28% Validated Probability: 43.29 % Difference (absolute value): 5.99%
# Group of etas # 110 of 120
# total time taken so far: 14 minutes and 43 seconds
# total minutes of validation: 15
# Probability differences --> MAX: 5.99% , MIN: 0.0%
# Preparing results to plot...
# Results ready to be displayed. 😎

# %%
save_object_to_disk(results, name='20210430b_C2_A1_1000_100000_3_6_20_validated_results_1000000', path=path)

# %%
validated_results = load_object_from_file(name='20210430b_C2_A1_1000_100000_3_6_20_validated_results_1000000', path='results/')

# %%
validated_results.export_to_csv(file_name='20210430b_validated_results', path='results/')

# %%
validated_results.plot_3channel_results('CRS (I=1.000 P=100.000)')

# %%
validated_results.plot_global_probabilities()

# %%
validated_results.plot_eta_success_probabilities()

# %%
validated_results.plot_eta_assignments()

# %%
validated_results.plot_eta_assignments(eta_pair_index=0)

# %%
validated_results.plot_eta_assignments(eta_pair_index=1)

# %%
validated_results.plot_eta_assignments(eta_pair_index=2)

# %%
validated_results.plot_eta_assignments(eta_pair_index=3)

# %%
validated_results.plot_eta_assignments(eta_pair_index=4)

# %%
validated_results.plot_eta_assignments(eta_pair_index=5)
