# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#From-simulation-results-loaded-previouly-extract-probabilities" data-toc-modified-id="From-simulation-results-loaded-previouly-extract-probabilities-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>From simulation results loaded previouly extract probabilities</a></span><ul class="toc-item"><li><span><a href="#Plot-the-probabilities-for-the-three-simulations" data-toc-modified-id="Plot-the-probabilities-for-the-three-simulations-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Plot the probabilities for the three simulations</a></span></li></ul></li><li><span><a href="#Compare-probabilities-obtained-from-both-simulations-(the-first-two)" data-toc-modified-id="Compare-probabilities-obtained-from-both-simulations-(the-first-two)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Compare probabilities obtained from both simulations (the first two)</a></span></li><li><span><a href="#Expected-results" data-toc-modified-id="Expected-results-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Expected results</a></span><ul class="toc-item"><li><span><a href="#What-are-the-theoretical-results-from-the-paper?" data-toc-modified-id="What-are-the-theoretical-results-from-the-paper?-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>What are the theoretical results from the paper?</a></span></li></ul></li><li><span><a href="#Compare-probabilities-from-simulations-with-the-theoretical-ones-from-the-paper" data-toc-modified-id="Compare-probabilities-from-simulations-with-the-theoretical-ones-from-the-paper-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Compare probabilities from simulations with the theoretical ones from the paper</a></span><ul class="toc-item"><li><span><a href="#Simulation-1-vs-theory-in-absolute-value" data-toc-modified-id="Simulation-1-vs-theory-in-absolute-value-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Simulation 1 vs theory in absolute value</a></span></li><li><span><a href="#Simulation-2-vs-theory-in-absolute-value" data-toc-modified-id="Simulation-2-vs-theory-in-absolute-value-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Simulation 2 vs theory in absolute value</a></span></li><li><span><a href="#Simulation-1-vs-theory-in-percentage" data-toc-modified-id="Simulation-1-vs-theory-in-percentage-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Simulation 1 vs theory in percentage</a></span></li></ul></li><li><span><a href="#Input-state-obtained-from-simulations-vs-theory" data-toc-modified-id="Input-state-obtained-from-simulations-vs-theory-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Input state obtained from simulations vs theory</a></span><ul class="toc-item"><li><span><a href="#Amplitude-$|1>$-from-1st-simulation" data-toc-modified-id="Amplitude-$|1>$-from-1st-simulation-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Amplitude $|1&gt;$ from 1st simulation</a></span></li><li><span><a href="#Amplitude-$|1>$-from-2nd-simulation" data-toc-modified-id="Amplitude-$|1>$-from-2nd-simulation-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Amplitude $|1&gt;$ from 2nd simulation</a></span></li><li><span><a href="#Amplitude-$|1>$-from-3rd-simulation" data-toc-modified-id="Amplitude-$|1>$-from-3rd-simulation-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Amplitude $|1&gt;$ from 3rd simulation</a></span></li><li><span><a href="#Comparing-both-amplitudes-from-simulation-1-and-2" data-toc-modified-id="Comparing-both-amplitudes-from-simulation-1-and-2-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Comparing both amplitudes from simulation 1 and 2</a></span></li><li><span><a href="#Comparing-both-amplitudes-from-simulation-2-and-3" data-toc-modified-id="Comparing-both-amplitudes-from-simulation-2-and-3-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Comparing both amplitudes from simulation 2 and 3</a></span></li><li><span><a href="#Amplitude-$|1>$-expected-from-theory" data-toc-modified-id="Amplitude-$|1>$-expected-from-theory-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Amplitude $|1&gt;$ expected from theory</a></span></li></ul></li><li><span><a href="#Amplitude-deltas-when-comparing-with-results-from-theory" data-toc-modified-id="Amplitude-deltas-when-comparing-with-results-from-theory-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Amplitude deltas when comparing with results from theory</a></span><ul class="toc-item"><li><span><a href="#1st-simulation-(in-absolute-value)" data-toc-modified-id="1st-simulation-(in-absolute-value)-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>1st simulation (in absolute value)</a></span></li><li><span><a href="#2nd-simulation-(in-absolute-value)" data-toc-modified-id="2nd-simulation-(in-absolute-value)-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>2nd simulation (in absolute value)</a></span></li><li><span><a href="#1st-simulation-(in-percentage)" data-toc-modified-id="1st-simulation-(in-percentage)-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>1st simulation (in percentage)</a></span></li><li><span><a href="#2nd-simulation-(in-percentage)" data-toc-modified-id="2nd-simulation-(in-percentage)-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>2nd simulation (in percentage)</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Print probabilities from results

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

from qcd.optimizationresults import GlobalOptimizationResults

# %%
results = GlobalOptimizationResults.load_results(file_names=['20210414a_C2_A2_100_100_3'],
                                                 path="../demo/data/")

# %%
1050/210
# Out:
# 5.0

# %%
results = GlobalOptimizationResults.load_results(file_names=['20210413a_C2_A1_1000_10000_2'],
                                                 path="results/")
# Out:
# number_eta_pairs: 210, eta_groups_length: 3
# number_third_channels: 0, without int conversion 0.014285714285714285
# first eta_group: [0.0, 0.07853981633974483, 0.0]
# number_eta_pairs: 210, eta_groups_length: 3
# number_third_channels: 0, without int conversion 0.014285714285714285
# first eta_group: [0.0, 0.07853981633974483, 0.0]

# %%
results.plot_probabilities()

# %%
results.plot_amplitudes()

# %% [markdown]
# ## From simulation results loaded previouly extract probabilities
# ### Plot the probabilities for the three simulations

# %%
results.plot_probabilities(results_index=0)

# %%
results.plot_probabilities(results_index=1)

# %%
results.plot_probabilities(results_index=2)

# %%
results.plot_probabilities(results_index=3)

# %%
results.plot_probabilities(results_index=4)

# %% [markdown]
# ## Compare probabilities obtained from both simulations (the first two)
# 1st simulation conditions
#
# 2nd simulation conditions: 3 optimizers and 400 iterations each

# %%
results.plot_probabilities_comparison(results_index1=0,
                                      results_index2=1)

# %%
results.plot_probabilities_comparison(results_index1=1,
                                      results_index2=2,
                                     vmin=-0.2,
                                     vmax=0.2)

# %% [markdown]
# ## Expected results
# ### What are the theoretical results from the paper?

# %%
results.plot_theoretical_probabilities(strategy='one_shot')

# %%
results.plot_theoretical_probabilities(strategy='one_shot_side_entanglement')

# %%
results.plot_theoretical_probabilities_comparison(first_strategy = 'one_shot_side_entanglement',
                                                  second_strategy= 'one_shot')
# Out:
# min: -2.220446049250313e-16, max 0.026917839007302935

# %%
results.plot_theoretical_improvement(vmin =0,
                                     vmax = 0.05)
# Out:
# min: 0.0, max 0.0450848360846548

# %% [markdown]
# ## Compare probabilities from simulations with the theoretical ones from the paper
# ### Simulation 1 vs theory in absolute value

# %%
results.plot_probabilities_comparison_with_theoretical_result(results_index=0,
                                                              strategy='one_shot_side_entanglement',
                                                              vmin= -0.05,
                                                              vmax= 0.05)

# %% [markdown]
# ### Simulation 2 vs theory in absolute value

# %%
results.plot_probabilities_comparison_with_theoretical_result(results_index=1,
                                                              strategy='one_shot_side_entanglement',
                                                              vmin= -0.1,
                                                              vmax= 0.1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-196a1b9bfeca> in <module>
# ----> 1 results.plot_probabilities_comparison_with_theoretical_result(results_index=1,
#       2                                                               strategy='one_shot_side_entanglement',
#       3                                                               vmin= -0.1,
#       4                                                               vmax= 0.1)
#
# ~/sandbox/01.upc-quantum/quantum-channel-discrimination/qcd/optimizationresults/globaloptimizationresults.py in plot_probabilities_comparison_with_theoretical_result(self, results_index, strategy, title, bar_label, vmin, vmax, cmap)
#     139         """ Plot probabilities comparing theoretical results """
#     140         delta_probs = cast(np.ndarray, self._theoretical_results[strategy].probabilities_matrix) - \
# ...

# %%
results.plot_probabilities_comparison_with_theoretical_result(results_index=2,
                                                              strategy='one_shot',
                                                              vmin= -0.2,
                                                              vmax= 0.2)

# %% [markdown]
# ### Simulation 1 vs theory in percentage

# %%
results.plot_probabilities_comparison_percentage(results_index=0,
                                                 strategy='one_shot_side_entanglement',
                                                 vmin= -5,
                                                 vmax= 5)

# %%
results.plot_probabilities_comparison_percentage(results_index=1,
                                                 strategy='one_shot_side_entanglement',
                                                 vmin= -40,
                                                 vmax= 40)

# %%
results.plot_probabilities_comparison_percentage(results_index=2,
                                                 strategy='one_shot',
                                                 vmin= -40,
                                                 vmax= 40)

# %% [markdown]
# ## Input state obtained from simulations vs theory
# ### Amplitude $|1>$ from 1st simulation

# %%
results.plot_amplitudes(results_index=0)

# %% [markdown]
# ### Amplitude $|1>$ from 2nd simulation

# %%
results.plot_amplitudes(results_index=1)

# %% [markdown]
# ### Amplitude $|1>$ from 3rd simulation

# %%
results.plot_amplitudes(results_index=2)

# %%
results.plot_amplitudes(results_index=3)

# %%
results.plot_amplitudes(results_index=4)

# %% [markdown]
# ### Comparing both amplitudes from simulation 1 and 2

# %%
results.plot_amplitudes_comparison(results_index1=0,
                                   results_index2=1)

# %% [markdown]
# ### Comparing both amplitudes from simulation 2 and 3

# %%
results.plot_amplitudes_comparison(results_index1=1,
                                   results_index2=2)

# %% [markdown]
# ### Amplitude $|1>$ expected from theory

# %%
results.plot_theoretical_amplitudes(strategy='one_shot')

# %%
results.plot_theoretical_amplitudes(strategy='one_shot_side_entanglement',
                                    vmin=0,
                                    vmax=0.5,)

# %%
results.plot_theoretical_amplitudes_comparison(first_strategy = 'one_shot',
                                               second_strategy= 'one_shot_side_entanglement',
                                               vmin=0,
                                               vmax=1,
                                               cmap='viridis')

# %% [markdown]
# ## Amplitude deltas when comparing with results from theory
# ### 1st simulation (in absolute value)

# %%
results.plot_amplitudes_comparison_with_theoretical_result(results_index=0,
                                                            strategy='one_shot_side_entanglement',
                                                            vmin = -0.5,
                                                            vmax = 0.5)

# %% [markdown]
# ### 2nd simulation (in absolute value)

# %%
results.plot_amplitudes_comparison_with_theoretical_result(results_index=1,
                                                            strategy='one_shot_side_entanglement',
                                                            vmin = -1,
                                                            vmax = 1)

# %%
results.plot_amplitudes_comparison_with_theoretical_result(results_index=2,
                                                            strategy='one_shot',
                                                            vmin = -1,
                                                            vmax = 1)

# %% [markdown]
# ### 1st simulation (in percentage)

# %%
results.plot_amplitudes_comparison_percentage(results_index=0,
                                              strategy='one_shot_side_entanglement',
                                              vmin = -100,
                                              vmax = 100)

# %% [markdown]
# ### 2nd simulation (in percentage)

# %%
results.plot_amplitudes_comparison_percentage(results_index=1,
                                              strategy='one_shot_side_entanglement',
                                              vmin = -100,
                                              vmax = 100)

# %%
results.plot_amplitudes_comparison_percentage(results_index=2,
                                              strategy='one_shot',
                                              vmin = -100,
                                              vmax = 100)
