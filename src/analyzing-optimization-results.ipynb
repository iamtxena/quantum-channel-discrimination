# %% [markdown]
# # Analyzing optimization results

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

from qcd.optimizationresults import OptimizationResults

# %%
results = OptimizationResults()

# %%
results.load_results(file_names=['20210320_results_CRS', '20210321_results_CRS'], path="results/")

# %%
results.load_results(file_names='20210331_ESCH_100iterations_0', path="results/")

# %%
results.plot_probabilities(results_index=0,
                           title='Probabilities from simulation',
                           bar_label='Probabilities value',
                           vmin=0.0,
                           vmax=1.0)

# %%
results.plot_probabilities(results_index=1,
                           title='Probabilities from simulation',
                           bar_label='Probabilities value',
                           vmin=0.0,
                           vmax=1.0)

# %%
results.plot_probabilities(results_index=2,
                           title='Probabilities from simulation',
                           bar_label='Probabilities value',
                           vmin=0.0,
                           vmax=1.0)

# %%
results.plot_probabilities_comparison(results_index1=0,
                                      results_index2=1,
                                      title = 'Difference in Probabilities from simulation',
                                      bar_label = 'Probabilities value',
                                      vmin= -0.1,
                                      vmax= 0.1)

# %%
results.plot_amplitudes(results_index=0,
                        title='Input state amplitude |1> obtained from simulation',
                        bar_label='Amplitude value',
                        vmin=0.0,
                        vmax= 1.0)

# %%
results.plot_amplitudes(results_index=1,
                        title='Input state amplitude |1> obtained from simulation',
                        bar_label='Amplitude value',
                        vmin=0.0,
                        vmax= 1.0)

# %%
results.plot_amplitudes(results_index=2,
                        title='Input state amplitude |1> obtained from simulation',
                        bar_label='Amplitude value',
                        vmin=0.0,
                        vmax= 1.0)

# %%
results.plot_amplitudes_comparison(results_index1=0,
                                   results_index2=1,
                                   title='Difference in Amplitudes (between simulations)',
                                   bar_label='Amplitude value',
                                   vmin=-1.0,
                                   vmax=1.0)
