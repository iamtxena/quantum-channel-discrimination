# %% [markdown]
# # UPC Quantum Engineering Final Project: Quantum Channel Discrimination
# ## IBM noisy simulation

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

import numpy as np
from numpy import pi
import math
from src.noisy_computations import run_all_circuits_one_lambda, plot_all_wireframe_bloch_list_one_lambda, Device
import warnings
warnings.filterwarnings('ignore')

# %%
points_theta = 10  # Points of Theta angle (pi/2) in Bloch sphere - min 2
points_phase = 7  # Points of Phase angle (2*pi) in Bloch sphere - min 2
# angles shift from first parameter, to the second one, with jumps using the third parameter
# angles_eta = np.append(np.arange(0, np.pi/2, np.pi/(points_theta*points_phase)), np.pi/2)
# setting attentuation levels (lambdas) from 0 to 1
# lambdas = np.append(np.arange(0, 1, 0.5), 1)
one_lambda = 0.4
# angles_eta = list(map(lambda one_lambda : np.arcsin(np.sqrt(one_lambda)), lambdas))
out_rx_angle=0
out_ry_angle=0

# %%
results = run_all_circuits_one_lambda(one_lambda=one_lambda, 
                                     points_theta=points_theta, 
                                     points_phase=points_phase, 
                                     iterations=2000, 
                                     out_rx_angle=out_rx_angle, 
                                     out_ry_angle=out_ry_angle,
                                     device=[Device.simulator, Device.fake_noise_simulator, Device.ibmq])
# Out:
# Job launched to qasm_simulator with id = 490603ce-6b26-45c2-9137-f83d0e1d4098
# Job launched to qasm_simulator(fake_athens) with id = e4423b3b-9d4e-4a47-8411-6c740de5ff20
# Running on current least busy device:  ibmq_belem
# Job launched to ibmq_belem with id = 605635c48debfebfd5f558e2

# %%
plot_all_wireframe_bloch_list_one_lambda(results, one_lambda, rows=3, cols=3)
